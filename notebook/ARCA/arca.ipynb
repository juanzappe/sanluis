# %%
import sys
from pathlib import Path
import csv 
import pandas as pd
import re

# Agregamos la carpeta src al path para poder importar
path_inicio = Path.cwd().parent.parent/"src"
sys.path.append(str(path_inicio))
from main import unificar_ingresos_csv
from utilidades.constantes import  PATRON_INGRESOS_PATH, INGRESOS_SALIDA_PATH, DATA_PATH, PATRON_EGRESOS_PATH, EGRESOS_SALIDA_PATH

# %% [markdown]
# ### UNIFICO LOS INGRESOS

# %%
unificar_ingresos_csv(DATA_PATH, PATRON_INGRESOS_PATH, INGRESOS_SALIDA_PATH)
# Out:
# 🚀 Iniciando proceso de unificación de ingresos ARCA...
#
# 📄 Leyendo: TOTAL_INGRESOS_2023.csv
# 📄 Leyendo: TOTAL_INGRESOS_2024.csv
# 📄 Leyendo: TOTAL_INGRESOS_2025_HASTA_SEPTIEMBRE.csv
# 📄 Leyendo: TOTAL_INGRESOS_2025_NOVIEMBRE.csv
# 📄 Leyendo: TOTAL_INGRESOS_2025_OCTUBRE.csv
#
# ✅ Unificación completada correctamente.
#    ➜ Archivo exportado: ..\..\2_data_unificada\ingresos_totales.csv
#    ➜ Total de filas: 129,772
#    ➜ Total de columnas: 29
#        Fecha de EmisiÃ³n  Tipo de Comprobante  Punto de Venta  NÃºmero Desde  \
# 0             2023-01-02                    1               8            259
# 1             2023-01-02                    6               8          19376
# 2             2023-01-02                    6               8          19406
# 3             2023-01-02                    6               8          19389
# 4             2023-01-02                    6               8          19377
# ...

# %% [markdown]
# ### UNIFICO EGRESOS

# %%
unificar_ingresos_csv(DATA_PATH, PATRON_EGRESOS_PATH, EGRESOS_SALIDA_PATH)
# Out:
# 🚀 Iniciando proceso de unificación de ingresos ARCA...
#
# 📄 Leyendo: TOTAL_EGRESOS_2023.csv
# 📄 Leyendo: TOTAL_EGRESOS_2024.csv
# 📄 Leyendo: TOTAL_EGRESOS_2025_HASTA_SEPTIEMBRE.csv
# 📄 Leyendo: TOTAL_EGRESOS_2025_NOVIEMBRE.csv
# 📄 Leyendo: TOTAL_EGRESOS_2025_OCTUBRE.csv
#
# ✅ Unificación completada correctamente.
#    ➜ Archivo exportado: ..\..\2_data_unificada\egresos_totales.csv
#    ➜ Total de filas: 8,114
#    ➜ Total de columnas: 31
#      Fecha de EmisiÃ³n  Tipo de Comprobante  Punto de Venta  NÃºmero Desde  \
# 0           2023-01-02                    1               4           1843
# 1           2023-01-02                    1               4          34356
# 2           2023-01-02                    1               3            765
# 3           2023-01-02                    1               2           1032
# 4           2023-01-02                    1              12           5626
# ...                ...                  ...             ...            ...
# ...

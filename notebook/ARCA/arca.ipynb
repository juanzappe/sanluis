# %%
import sys
from pathlib import Path
import csv 
import pandas as pd
import re

# Agregamos la carpeta src al path para poder importar
path_inicio = Path.cwd().parent.parent/"src"
sys.path.append(str(path_inicio))
from main import unificar_ingresos_csv
from utilidades.constantes import  PATRON_INGRESOS_PATH, INGRESOS_SALIDA_PATH, DATA_PATH

# %%
unificar_ingresos_csv(DATA_PATH, PATRON_INGRESOS_PATH, INGRESOS_SALIDA_PATH)
# Out:
# 🚀 Iniciando proceso de unificación de ingresos ARCA...
#
# 📄 Leyendo: TOTAL_INGRESOS_2023.csv
# 📄 Leyendo: TOTAL_INGRESOS_2024.csv
# 📄 Leyendo: TOTAL_INGRESOS_2025_HASTA_SEPTIEMBRE.csv
#
# ✅ Unificación completada correctamente.
#    ➜ Archivo exportado: ..\..\2_data_procesada\ingresos_totales.csv
#    ➜ Total de filas: 123,180
#    ➜ Total de columnas: 29
#        Fecha de EmisiÃ³n  Tipo de Comprobante  Punto de Venta  NÃºmero Desde  \
# 0             2023-01-02                    1               8            259
# 1             2023-01-02                    6               8          19376
# 2             2023-01-02                    6               8          19406
# 3             2023-01-02                    6               8          19389
# 4             2023-01-02                    6               8          19377
# ...                  ...                  ...             ...            ...
# 123175        2025-09-30                    6               8         130908
# 123176        2025-09-30                    6               8         130911
# 123177        2025-09-30                    6               8         130934
# 123178        2025-09-30                    6               8         130942
# 123179        2025-09-30                    6               8         130990
#
#         NÃºmero Hasta  CÃ³d. AutorizaciÃ³n  Tipo Doc. Receptor  \
# 0                 259       73010447159945                  80
# 1               19376       73010419656708                  80
# 2               19406       73010457762163                  80
# 3               19389       73010438036220                  80
# 4               19377       73010419802088                  80
# ...               ...                  ...                 ...
# 123175         130908       75390978307092                  99
# 123176         130911       75390985324034                  99
# 123177         130934       75390995763347                  99
# 123178         130942       75390999176248                  99
# 123179         130990       75390044233278                  99
#
#         Nro. Doc. Receptor             DenominaciÃ³n Receptor Tipo Cambio  \
# 0              20083459728  SUCESION DE CROCCE ARMANDO HECTOR        1,00
# 1              20111111112                      CUIT GENERICO        1,00
# 2              20111111112                      CUIT GENERICO        1,00
# 3              20111111112                      CUIT GENERICO        1,00
# 4              20111111112                      CUIT GENERICO        1,00
# ...                    ...                                ...         ...
# 123175                   0                                NaN        1,00
# 123176                   0                                NaN        1,00
# 123177                   0                                NaN        1,00
# 123178                   0                                NaN        1,00
# 123179                   0                                NaN        1,00
#
#         ... Imp. Neto Gravado IVA 21% IVA 27% Imp. Neto Gravado IVA 27%  \
# 0       ...                   2066,12     NaN                       NaN
# 1       ...                   1636,36     NaN                       NaN
# 2       ...                    743,80     NaN                       NaN
# 3       ...                   1322,31     NaN                       NaN
# 4       ...                   1157,02     NaN                       NaN
# ...     ...                       ...     ...                       ...
# 123175  ...                  11735,54     NaN                       NaN
# 123176  ...                   7438,02     NaN                       NaN
# 123177  ...                   7438,02     NaN                       NaN
# 123178  ...                   1652,89     NaN                       NaN
# 123179  ...                   2892,56     NaN                       NaN
#
#        Imp. Neto Gravado Total Imp. Neto No Gravado Imp. Op. Exentas  \
# 0                      2066,12                 0,00             0,00
# 1                      1636,36                 0,00             0,00
# 2                       743,80                 0,00             0,00
# 3                      1322,31                 0,00             0,00
# 4                      1157,02                 0,00             0,00
# ...                        ...                  ...              ...
# 123175                11735,54                 0,00             0,00
# 123176                 7438,02                 0,00             0,00
# 123177                 7438,02                 0,00             0,00
# 123178                 1652,89                 0,00             0,00
# 123179                 2892,56                 0,00             0,00
#
#        Otros Tributos Total IVA Imp. Total  \
# 0                0,00    433,88    2500,00
# 1                0,00    343,64    1980,00
# 2                0,00    156,20     900,00
# 3                0,00    277,69    1600,00
# 4                0,00    242,98    1400,00
# ...               ...       ...        ...
# 123175           0,00   2464,46   14200,00
# 123176           0,00   1561,98    9000,00
# 123177           0,00   1561,98    9000,00
# 123178           0,00    347,11    2000,00
# 123179           0,00    607,44    3500,00
#
#                                       Origen
# 0                        TOTAL_INGRESOS_2023
# 1                        TOTAL_INGRESOS_2023
# 2                        TOTAL_INGRESOS_2023
# 3                        TOTAL_INGRESOS_2023
# 4                        TOTAL_INGRESOS_2023
# ...                                      ...
# 123175  TOTAL_INGRESOS_2025_HASTA_SEPTIEMBRE
# 123176  TOTAL_INGRESOS_2025_HASTA_SEPTIEMBRE
# 123177  TOTAL_INGRESOS_2025_HASTA_SEPTIEMBRE
# 123178  TOTAL_INGRESOS_2025_HASTA_SEPTIEMBRE
# 123179  TOTAL_INGRESOS_2025_HASTA_SEPTIEMBRE
#
# [123180 rows x 29 columns]
